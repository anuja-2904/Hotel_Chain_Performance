# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Downloads/Hotel_Chain_Performance.csv")

# %%
df.head()
# Out:
#   Booking_ID            Hotel_Name       City Hotel_Type        Date  \
# 0  BKG573122    Orbit Budget DEL23      Delhi        NaN  2024-05-29
# 1  BKG837779    Orbit Luxury CHE05    Chennai     Luxury  2024-04-10
# 2  BKG292771    Orbit Luxury MUM07     Mumbai     Luxury  2023-10-17
# 3  BKG902521  Orbit Business HYD16  Hyderabad   Business  2023-04-19
# 4  BKG380131  Orbit Business BEN06  Bengaluru   Business  2023-01-08
#
#    Rooms_Available  Rooms_Booked  Occupancy_Rate  Avg_Room_Price  \
# 0               66            52           78.79         3370.38
# 1              186           139           74.73        12346.26
# 2              220           206           93.64        15000.00
# 3              111            82           73.87         5744.05
# 4              114            71           62.28         6063.51
#
#    Daily_Revenue  Operating_Cost  Net_Profit  Profit_Margin_Percent  \
# 0      175259.56         60000.0   115259.56                  65.77
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Booking_ID                3000 non-null   object
#  1   Hotel_Name                3000 non-null   object
#  2   City                      3000 non-null   object
#  3   Hotel_Type                2881 non-null   object
#  4   Date                      3000 non-null   object
#  5   Rooms_Available           3000 non-null   int64
#  6   Rooms_Booked              3000 non-null   int64
#  7   Occupancy_Rate            3000 non-null   float64
#  8   Avg_Room_Price            2879 non-null   float64
#  9   Daily_Revenue             3000 non-null   float64
#  10  Operating_Cost            3000 non-null   float64
#  11  Net_Profit                3000 non-null   float64
#  12  Profit_Margin_Percent     3000 non-null   float64
# ...

# %%
df.describe(include = "all")
# Out:
#        Booking_ID          Hotel_Name  City Hotel_Type        Date  \
# count        3000                3000  3000       2881        3000
# unique       2950                 772    12          4         715
# top     BKG673573  Orbit Resort MUM10  Pune     Luxury  2023-01-03
# freq            2                  11   509        741          13
# mean          NaN                 NaN   NaN        NaN         NaN
# std           NaN                 NaN   NaN        NaN         NaN
# min           NaN                 NaN   NaN        NaN         NaN
# 25%           NaN                 NaN   NaN        NaN         NaN
# 50%           NaN                 NaN   NaN        NaN         NaN
# 75%           NaN                 NaN   NaN        NaN         NaN
# max           NaN                 NaN   NaN        NaN         NaN
#
#         Rooms_Available  Rooms_Booked  Occupancy_Rate  Avg_Room_Price  \
# count       3000.000000   3000.000000     3000.000000     2879.000000
# ...

# %% [markdown]
# 1. **Booking_ID**
# - As the count in Booking_ID feature is 3000 it has no missing values
# - In this feature there are **2950 unique values**
# - **BKG673573** is the most **frequent Booking_ID** which has been **repeated 2 times**
#
# 2. **Hotel_Name**
# - As the count in Hotel_Name feature is 3000 it has no missing values
# - In this feature there are **772 unique values**
# - **Orbit Resort MUM10** is the most **frequent Hotel_Name** which has been **repeated 11 times**
#
# 3. **City**
# - As the count in City feature is 3000 it has no missing values
# - In this feature there are **12 unique values**
# - **Pune** is the most **frequent City** which has been **repeated 509 times**
#
# 4. **Hotel_Type**
# - As the count in Hotel_Type feature is 2881 it has no missing values
# - In this feature there are **4 unique values**
# - **Luxury** is the most **frequent Hotel_Type** which has been **repeated 741 times**
#
# 5. **Date**
# - As the count in Date feature is 3000 it has no missing values
# - In this feature there are **715 unique values**
# - **2023-01-03** is the most **frequent Date** which has been **repeated 13 times**
#
# 6. **Rooms_Available**
# - As the count in the Rooms_Available feature is 3000 it has no missing values
# - The **mean average is 126.34** and **standard deviation is 50.09** in this observation we see that the data is less variated
# - In this feature **41 is minimum value** and **220 is the maximum value**
# - In this feature **25%** of Rooms_Available lies **below 84**
# - In this feature **50%** of Rooms_Available lies **below 121**
# - In this feature **75%** of Rooms_Available lies **below 161**
#
# 7. **Rooms_Booked**
# - As the count in the Rooms_Booked feature is 3000 it has no missing values
# - The **mean average is 92.76** and **standard deviation is 39.94** in this observation we see that the data is less variated
# - In this feature **23 is minimum value** and **216 is the maximum value**
# - In this feature **25%** of Rooms_Booked lies **below 60**
# - In this feature **50%** of Rooms_Booked lies **below 89**
# - In this feature **75%** of Rooms_Booked lies **below 118**
#
# 8. **Occupancy_Rate**
# - As the count in the Occupancy_Rate feature is 3000 it has no missing values
# - The **mean average is 73.02** and **standard deviation is 10.49** in this observation we see that the data is less variated
# - In this feature **35.38 is minimum value** and **98.63 is the maximum value**
# - In this feature **25%** of Occupancy_Rate lies **below 65.81**
# - In this feature **50%** of Occupancy_Rate lies **below 73.08**
# - In this feature **75%** of Occupancy_Rate lies **below 80**
#
# 9. **Avg_Room_Price**
# - As the count in the Avg_Room_Price feature is 2879 it has no missing values
# - The **mean average is 8415.136** and **standard deviation is 5698.260** in this observation we see that the data is less variated
# - In this feature **1829.300 is minimum value** and **79252.077 is the maximum value**
# - In this feature **25%** of Avg_Room_Price lies **below 4503.030**
# - In this feature **50%** of Avg_Room_Price lies **below 7670.160**
# - In this feature **75%** of Avg_Room_Price lies **below 11158.670**
#
# 10. **Daily_Revenue**
# - As the count in the Daily_Revenue feature is 3000 it has no missing values
# - The **mean average is 9.414911** and **standard deviation is 9.716867** in this observation we see that the data is variated
# - In this feature **5.009188 is minimum value** and **1.431827 is the maximum value**
# - In this feature **25%** of Daily_Revenue lies **below 2.774789**
# - In this feature **50%** of Daily_Revenue lies **below 6.704459**
# - In this feature **75%** of Daily_Revenue lies **below 1.324880**
#
# 11. **Operating_Cost**
# - As the count in the Operating_Cost feature is 3000 it has no missing values
# - The **mean average is 64079.357** and **standard deviation is 29395.055** in this observation we see that the data is less variated
# - In this feature **60000 is minimum value** and **358493.338 is the maximum value**
# - In this feature **25%** of Operating_Cost lies **below 60000**
# - In this feature **50%** of Operating_Cost lies **below 60000**
# - In this feature **75%** of Operating_Cost lies **below 60000**
#
# 12. **Net_Profit**
# - As the count in the Net_Profit feature is 3000 it has no missing values
# - The **mean average is 8.592505** and **standard deviation is 8.189404** in this observation we see that the data is less variated
# - In this feature **-9.908120 is minimum value** and **8.980672 is the maximum value**
# - In this feature **25%** of Net_Profit lies **below 2.164370**
# - In this feature **50%** of Net_Profit lies **below 6.114907**
# - In this feature **75%** of Net_Profit lies **below 1.283420**
#
# 13. **Profit_Margin_Percent**
# - As the count in the Profit_Margin_Percent feature is 3000 it has no missing values
# - The **mean average is 82.61** and **standard deviation is 19.21** in this observation we see that the data is less variated
# - In this feature **-19.78 is minimum value** and **98.15 is the maximum value**
# - In this feature **25%** of Profit_Margin_Percent lies **below 2.164370**
# - In this feature **50%** of Profit_Margin_Percent lies **below 6.114907**
# - In this feature **75%** of Profit_Margin_Percent lies **below 1.283420**
#
# 14. **Customer_Rating**
# - As the count in the Customer_Rating feature is 2876 it has no missing values
# - The **mean average is 3.79** and **standard deviation is 0.42** in this observation we see that the data is less variated
# - In this feature **2.3 is minimum value** and **5 is the maximum value**
# - In this feature **25%** of Customer_Rating lies **below 3.5**
# - In this feature **50%** of Customer_Rating lies **below 3.8**
# - In this feature **75%** of Customer_Rating lies **below 4.1**
#
# 15. **Cancellations**
# - As the count in the Cancellations feature is 2882 it has no missing values
# - The **mean average is 1.33** and **standard deviation is 1.26** in this observation we see that the data is less variated
# - In this feature **0 is minimum value** and **7 is the maximum value**
# - In this feature **25%** of Cancellations lies **below 0**
# - In this feature **50%** of Cancellations lies **below 1**
# - In this feature **75%** of Cancellations lies **below 2**
#
# 16. **Event_Season**
# - As the count in Event_Season feature is 3000 it has no missing values
# - In this feature there are **8 unique values**
# - **Off Season** is the most **frequent Event_Season** which has been **repeated 1759 times**
#
# 17. **Repeat_Customers_Percent**
# - As the count in the Repeat_Customers_Percent feature is 3000 it has no missing values
# - The **mean average is 63.66** and **standard deviation is 7.15** in this observation we see that the data is less variated
# - In this feature **37.89 is minimum value** and **82.90 is the maximum value**
# - In this feature **25%** of Repeat_Customers_Percent lies **below 58.77**
# - In this feature **50%** of Repeat_Customers_Percent lies **below 63.61**
# - In this feature **75%** of Repeat_Customers_Percent lies **below 68.49**

# %%
df.isna().sum()
# Out:
# Booking_ID                    0
# Hotel_Name                    0
# City                          0
# Hotel_Type                  119
# Date                          0
# Rooms_Available               0
# Rooms_Booked                  0
# Occupancy_Rate                0
# Avg_Room_Price              121
# Daily_Revenue                 0
# Operating_Cost                0
# Net_Profit                    0
# Profit_Margin_Percent         0
# Customer_Rating             124
# Cancellations               118
# Event_Season                  0
# Repeat_Customers_Percent      0
# dtype: int64

# %%
df['Hotel_Type'] = df['Hotel_Type'].fillna("Unknown")

# %%
df['Avg_Room_Price'] = df['Avg_Room_Price'].fillna(df['Avg_Room_Price'].mean())

# %%
df['Customer_Rating'] = df['Customer_Rating'].fillna(df['Customer_Rating'].mean())

# %%
df['Cancellations'] = df['Cancellations'].fillna(df['Cancellations'].mean())

# %%
df['City'] = df['City'].replace('mumbai','Mumbai')
df['City'] = df['City'].replace('pune','Pune')
df['City'] = df['City'].replace('delhi','Delhi')
df['City'] = df['City'].replace('hyderabad','Hyderabad')
df['City'] = df['City'].replace('chennai','Chennai')
df['City'] = df['City'].replace('bengaluru','Bengaluru')

df['Event_Season'] = df['Event_Season'].replace('off season','Off Season')
df['Event_Season'] = df['Event_Season'].replace('wedding','Wedding')
df['Event_Season'] = df['Event_Season'].replace('festive','Festive')
df['Event_Season'] = df['Event_Season'].replace('conference','Conference')

# %%
df.duplicated().sum()
# Out:
# 44

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (2956, 17)

# %%
df['Date'] = pd.to_datetime(df["Date"])

# %%
df['Month'] = df['Date'].dt.month

# %%
df['Year'] = df['Date'].dt.year

# %%
df["month_name"]=df["Date"].dt.month_name()

# %%
df["day_name"]=df["Date"].dt.day_name()

# %%
df["quarter"]=df["Date"].dt.quarter

# %%
df.groupby('City')['Occupancy_Rate'].mean().sort_values(ascending=False)
# Out:
# City
# Hyderabad    74.011454
# Bengaluru    73.899700
# Mumbai       73.156438
# Pune         72.937292
# Chennai      72.512637
# Delhi        71.827093
# Name: Occupancy_Rate, dtype: float64

# %%
df.groupby('Hotel_Type')['Occupancy_Rate'].mean().sort_values(ascending=False)
# Out:
# Hotel_Type
# Business    77.117786
# Luxury      73.820479
# Unknown     72.681795
# Resort      71.886895
# Budget      69.529307
# Name: Occupancy_Rate, dtype: float64

# %%
df.groupby('Hotel_Name')['Customer_Rating'].mean().sort_values(ascending=False)
# Out:
# Hotel_Name
# orbit business hyd25    4.90
# Orbit Luxury HYD18      4.60
# orbit business hyd11    4.60
# Orbit Budget MUM27      4.50
# orbit resort mum28      4.50
#                         ...
# Orbit Budget DEL05      2.90
# Orbit Resort HYD06      2.85
# Orbit Luxury BEN23      2.85
# orbit luxury che29      2.80
# Orbit Luxury HYD13      2.60
# Name: Customer_Rating, Length: 772, dtype: float64

# %%
plt.hist(df['Rooms_Available'], color='cyan', edgecolor='black')
plt.title('Rooms Available Distribution')
plt.xlabel('Rooms Available')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Mostly rooms are available between 100 to 125**
# - **There are very less rooms available between 175 to 200**
# - **Also very less rooms below 50**
# -

# %%
plt.hist(df['Rooms_Booked'], color='cyan', edgecolor='black')
plt.title('Rooms Booked Distribution')
plt.xlabel('Rooms_Booked')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Most of rooms are booked 75 to 100**
# - **Above 150 very less rooms are booked**
# - It is **Right Skewed Distribution**

# %%
plt.hist(df['Occupancy_Rate'], color='cyan', edgecolor='black')
plt.title('Occupancy_Rate Distribution')
plt.xlabel('Occupancy_Rate')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **The median is between 72 to 75**
# - **There are few outliers below 40**
# - **Occupany rate is 100 percent**
# - It is a **Normal Distribution some hotels have highest occupancy rate**

# %%
plt.hist(df['Avg_Room_Price'], color='cyan', edgecolor='black')
plt.title('Avg_Room_Price Distribution')
plt.xlabel('Avg_Room_Price')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Most of rooms have average price between 0 to 10000**
# - **Less rooms have average price above 10000**
# - **There are very few rooms which have average price above 20000**
# - It is **Right Skewed Distribution few rooms have high average prices**

# %%
plt.hist(df['Daily_Revenue'], color='cyan', edgecolor='black')
plt.title('Daily_Revenue Distribution')
plt.xlabel('Daily_Revenue')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Mostly daily revenue is between 0.0 to 0.2**
# - **Less revenue above 0.2**
# - **Very less revenue above 0.4**
# - It is **Right skewed Distribution few hotels have highest daily revenue**

# %%
plt.hist(df['Operating_Cost'], color='cyan', edgecolor='black')
plt.title('Operating_Cost Distribution')
plt.xlabel('Operating_Cost')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Mostly operating cost is between 50000 to 100000**
# - **Very less operating cost above 200000**
# - It is **Right Skewed Distribution**

# %%
plt.hist(df['Net_Profit'], color='cyan', edgecolor='black')
plt.title('Net_Profit Distribution')
plt.xlabel('Net_Profit')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Majority of net profit is between 0 to 1**
# - **There are outliers above 4**
# - It is **Right Skewed Distribution**

# %%
plt.hist(df['Profit_Margin_Percent'], color='cyan', edgecolor='black')
plt.title('Profit_Margin_Percent Distribution')
plt.xlabel('Profit_Margin_Percent')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Majority of profit margin is between 50 to 100**
# - **Median is between 85 to 90**
# - **There are outliers below 40**
# - It is **Left Skewed Distribution**

# %%
plt.hist(df['Customer_Rating'], color='cyan', edgecolor='black')
plt.title('Customer_Rating Distribution')
plt.xlabel('Customer_Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Majority of customer rating is between 3.5 to 4.0**
# - **Median is between 3.6 to 3.8**
# - **There are few outliers below 2.6 and above 4.8**
# - It is **Normal Distribution**

# %%
plt.hist(df['Cancellations'], color='cyan', edgecolor='black')
plt.title('Cancellations Distribution')
plt.xlabel('Cancellations')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Mostly cancellations of booking is between 0 to 2**
# - **Very less cancellations above 5**
# - It is **Right Skewed Distribution**

# %%
plt.hist(df['Repeat_Customers_Percent'], color='cyan', edgecolor='black')
plt.title('Repeat_Customers_Percent Distribution')
plt.xlabel('Repeat_Customers_Percent')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - **Majority of repeat customers percent is between 55 to 60**
# - **Very few repeat customers below 50 and above 80**
# - It is **normal Distribution**

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='City', hue='Hotel_Type', data=df)
plt.title("City wise Hotel_Type count")
plt.xlabel("City")
plt.show()

# %% [markdown]
# The distribution shows that Delhi and Bengaluru have highest count of customers for Luxury hotel type, Chennai and Mumbai have highest count for Resort type, Hyderabad have highest count for Business type hotels and Pune have highest count for Budget friendly hotel types

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='Event_Season', hue='Hotel_Type', data=df)
plt.title("Event_Season wise Hotel_Type count")
plt.xlabel("Event_Season")
plt.show()

# %% [markdown]
# The distribution shows that there is highest count of customers in Off season, mostly peoples visits hotels in Off seasons Budget type have highest count for customers.
# In wedding season peoples mostly visit Luxury types and In Festive seasons budget have highest count. For Conference peoples highly choose resorts.

# %%
plt.figure(figsize=(15,8))
sns.countplot(x='day_name', hue='Event_Season', data=df)
plt.title("day_name wise Event_Season count")
plt.xlabel("day_name")
plt.show()

# %% [markdown]
# The visualization indicates that in off season all days have high count of customers. For Wedding there is highest count of customers followed by Festive season.

# %%
plt.scatter(df["Rooms_Booked"],df["Occupancy_Rate"])
plt.xlabel("Rooms_Booked")
plt.ylabel("Occupancy_Rate")
plt.title("Rooms_Booked wise Occupancy_Rate")
plt.show()

# %% [markdown]
# The distribution shows that there is positive relationship between rooms booked and occupancy rate as the number of rooms booked increases occupancy rate also increases.

# %%
plt.scatter(df["Occupancy_Rate"],df["Net_Profit"])
plt.xlabel("Occupancy_Rate")
plt.ylabel("Net_Profit")
plt.title("Occupancy_Rate wise Net_Profit")
plt.show()

# %% [markdown]
# The distribution shows that there is positive relationship between occupancy rate and net profit as the occupancy rate increases net profit also increases.

# %%
plt.scatter(df["Repeat_Customers_Percent"],df["Customer_Rating"])
plt.xlabel("Repeat_Customers_Percent")
plt.ylabel("Customer_Rating")
plt.title("Repeat_Customers_Percent wise Customer_Rating")
plt.show()

# %% [markdown]
# The distribution shows that there is positive relationship between repeat customers and customers rating as the repeat customers percent increases rating also increases.

# %%
plt.scatter(df["Cancellations"],df["Rooms_Booked"])
plt.xlabel("Cancellations")
plt.ylabel("Rooms_Booked")
plt.title("Cancellations wise Rooms_Booked")
plt.show()

# %% [markdown]
# The distribution shows that there is negative relationship between cancellations and rooms booked as the cancellations increases number of rooms booked decreases.

# %%
sns.boxplot(x="Hotel_Type", y="Avg_Room_Price", data=df)
plt.title("Distribution of Hotel_Type Compared to Avg_Room_Price")
plt.xlabel("Hotel_Type")
plt.ylabel("Avg_Room_Price")
plt.show()

# %% [markdown]
# The distribution shows that Luxury and Resort hotels have highest average room prices, Budget hotels have lowest room prices.

# %%
sns.boxplot(x="City", y="Daily_Revenue", data=df)
plt.title("Distribution of City Compared to Daily_Revenue")
plt.xlabel("City")
plt.ylabel("Daily_Revenue")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The visualization indicates that Delhi,Mumbai and Bengaluru have highest median of daily revenue and Chennai, Hyderabad and Pune have lowest median

# %%
sns.boxplot(x="Event_Season", y="Occupancy_Rate", data=df)
plt.title("Distribution of Event_Season Compared to Occupancy_Rate")
plt.xlabel("Event_Season")
plt.ylabel("Occupancy_Rate")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The visualization indicates that Wedding, Off Season and Conference have highest median occupancy rate and Festive season have less median which means peoples visits less on festive seasons

# %%
sns.boxplot(x='Hotel_Type', y='Customer_Rating', data=df)
plt.title('Customer Rating by Hotel Type')
plt.xlabel('Hotel Type')
plt.ylabel('Customer Rating')
plt.show()

# %% [markdown]
# - **All hotel types have medain between 3.6 and 4.0**
# - **Business have highest median**
# - **Budget have lowest median**

# %%
sns.boxplot(x='Event_Season', y='Net_Profit', data=df)
plt.title('Net_Profit by Event_Season')
plt.xlabel('Event_Season')
plt.ylabel('Net_Profit')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - **All event seasons have almost similar median**
# - **Off season have extreme high level outliers**

# %%
sns.regplot(x="Avg_Room_Price",y="Daily_Revenue",data=df)
plt.title("Distribution of Avg_Room_Price compared to Daily_Revenue")
plt.xlabel("Avg_Room_Price")
plt.ylabel("Daily_Revenue")
plt.show()

# %% [markdown]
# The visualization indicates that there is upward trend in average room price and daily revenue, which means there is positive relationship as the average room price increases daily revenue also increases.

# %%
sns.regplot(x="Occupancy_Rate",y="Net_Profit",data=df)
plt.title("Distribution of Occupancy_Rate compared to Net_Profit")
plt.xlabel("Occupancy_Rate")
plt.ylabel("Net_Profit")
plt.show()

# %% [markdown]
# The visualization indicates that there is upward trend in occupancy rate and net profit, means there is positive relationship as the occupancy rate increases net profit also increases.

# %%
sns.regplot(x="Operating_Cost",y="Net_Profit",data=df)
plt.title("Distribution of Operating_Cost compared to Net_Profit")
plt.xlabel("Operating_Cost")
plt.ylabel("Net_Profit")
plt.show()

# %% [markdown]
# The visualization indicates that there is upward trend in operating cost and net profit, means there is positive relationship as the operating cost increases net profit also increases.

# %%
sns.regplot(x="Rooms_Booked",y="Daily_Revenue",data=df)
plt.title("Distribution of Rooms_Booked compared to Daily_Revenue")
plt.xlabel("Rooms_Booked")
plt.ylabel("Daily_Revenue")
plt.show()

# %% [markdown]
# The visualization indicates that there is upward trend in rooms booked and daily revenue, means there is positive relationship as the rooms booked increases dailt revenue also increases.

# %%
sns.regplot(x="Repeat_Customers_Percent",y="Customer_Rating",data=df)
plt.title("Distribution of Repeat_Customers_Percent compared to Customer_Rating")
plt.xlabel("Repeat_Customers_Percent")
plt.ylabel("Customer_Rating")
plt.show()

# %% [markdown]
# The visualization indicates that there is upward trend in repeat customer percent and customer rating, means there is positive relationship as the  repeat customers percent increases customer rating also increases.

# %%
sns.regplot(x="Rooms_Available",y="Rooms_Booked",data=df)
plt.title("Distribution of Rooms_Available compared to Rooms_Booked")
plt.xlabel("Rooms_Available")
plt.ylabel("Rooms_Booked")
plt.show()

# %% [markdown]
# The visualization indicates that there is upward trend in rooms availabel and rooms booked, means there is positive relationship as the rooms availabel increases rooms booked also increases.

# %%
sns.regplot(x="Cancellations",y="Occupancy_Rate",data=df)
plt.title("Distribution of Cancellations compared to Occupancy_Rate")
plt.xlabel("Cancellations")
plt.ylabel("Occupancy_Rate")
plt.show()

# %% [markdown]
# The visualization indicates that there is downward trend in cancellations and occupancy rate, means there is negative relationship as the cancellations increases occupancy rate decreases.

# %%
sns.regplot(x="Profit_Margin_Percent",y="Net_Profit",data=df)
plt.title("Distribution of Profit_Margin_Percent compared to Net_Profit")
plt.xlabel("Profit_Margin_Percent")
plt.ylabel("Net_Profit")
plt.show()

# %% [markdown]
# The visualization indicates that there is upward trend in profit margin percent and net profit, means there is positive relationship as the profit margin percent increases net profit also increases.

# %%
Daily_Revenue_by_Hotel_Type = df.groupby('Hotel_Type')['Daily_Revenue'].sum()

plt.pie(Daily_Revenue_by_Hotel_Type, labels=Daily_Revenue_by_Hotel_Type.index, autopct='%1.1f%%', startangle=90)

plt.title('Daily_Revenue_by_Hotel_Type')
plt.axis('equal')  
plt.show()

# %% [markdown]
# - **Luxury Hotel type have highest daily revenue around 57.5%**
# - **Budget have very low daily revenue around 4.2%**
# - **Business also have low daily revenue around 14.2%**
# - **Resort have dail revenue around 24.1%**

# %%
Avg_Room_Price_by_Hotel_Type = df.groupby('Hotel_Type')['Avg_Room_Price'].sum()

plt.pie(Avg_Room_Price_by_Hotel_Type, labels=Avg_Room_Price_by_Hotel_Type.index, autopct='%1.1f%%', startangle=90)

plt.title('Avg_Room_Price_by_Hotel_Type')
plt.axis('equal')  
plt.show()

# %% [markdown]
# - **Highest average room price is of luxury hotels around 43.9%**
# - **Budget have low average room price around 10.4%**
# - **Business have average room price around 18.7%**
# - **Resort have average room price around 27.0%**

# %%
Customer_Rating_by_Hotel_Type = df.groupby('Hotel_Type')['Customer_Rating'].sum()

plt.pie(Customer_Rating_by_Hotel_Type, labels=Customer_Rating_by_Hotel_Type.index, autopct='%1.1f%%', startangle=90)

plt.title('Customer_Rating_by_Hotel_Type')
plt.axis('equal')  
plt.show()

# %% [markdown]
# - **Luxury hotels have highest customer ratings around 28.8%**
# - **Budget and Business have similar customer ratings around 24.1%**
# - **Resort have customer rating around 23.0%**

# %%
plt.bar(df['City'],df['Avg_Room_Price'], color ="skyblue")
plt.title("Avg_Room_Price by City")
plt.xlabel('City')
plt.ylabel('Avg_Room_Price')
plt.xticks(rotation=-60)
plt.show()

# %% [markdown]
# - **Mumbai and Bengaluru have highest room prices around around 78000 to 79000**
# - **Delhi also have highest room prices around 75000**
# - **pune and chennai have low average room prices**

# %%
plt.bar(df['City'],df['Daily_Revenue'], color ="skyblue")
plt.title("Daily_Revenue by City")
plt.xlabel('City')
plt.ylabel('Daily_Revenue')
plt.xticks(rotation=-60)
plt.show()

# %% [markdown]
# - **Mumbai have highest daily revenue**
# - **pune and chennai have lowest daily revenue**

# %%
plt.bar(df['City'],df['Repeat_Customers_Percent'], color ="skyblue")
plt.title("Repeat_Customers_Percent by City")
plt.xlabel('City')
plt.ylabel('Repeat_Customers_Percent')
plt.xticks(rotation=-60)
plt.show()

# %% [markdown]
# - **Mostly all cities have highest repeat customers around 80**
# - **chennai have less repeat customers around 70**

# %%
plt.bar(df['Event_Season'],df['Rooms_Booked'], color ="skyblue")
plt.title("Rooms_Booked by Event_Season")
plt.xlabel('Event_Season')
plt.ylabel('Rooms_Booked')
plt.xticks(rotation=-60)
plt.show()

# %% [markdown]
# - **Highest rooms booked on off season**
# - **Less rooms booked on festive season**
# - **In wedding season also there are very many rooms booked**

# %%
sns.scatterplot(x="Occupancy_Rate", y="Net_Profit", hue="Event_Season", data=df)
plt.title("Scatterplot for analaysing Occupancy_Rate and Net_Profit with respect to Event_Season")
plt.xlabel("Occupancy_Rate")
plt.ylabel("Net_Profit")
plt.show()

# %% [markdown]
# The visualization indicates that there is positive relationship in occupancy rate and net profit and not single season is dominating the net profit.

# %%
sns.scatterplot(x="Rooms_Booked", y="Daily_Revenue", hue="City", data=df)
plt.title("Scatterplot for analaysing Rooms_Booked and Daily_Revenue with respect to City")
plt.xlabel("Rooms_Booked")
plt.ylabel("Daily_Revenue")
plt.show()

# %% [markdown]
# The visualization indicates that there is positive relationship between rooms booked and daily revenue as the rooms booked increases revenue also increases.
# There is not a single city dominating the revenue.

# %%
sns.scatterplot(x="Repeat_Customers_Percent", y="Customer_Rating", hue="Hotel_Type", data=df)
plt.title("Scatterplot for analaysing Repeat_Customers_Percent and Customer_Rating with respect to Hotel_Type")
plt.xlabel("Repeat_Customers_Percent")
plt.ylabel("Customer_Rating")
plt.show()

# %% [markdown]
# The visualization indicates that there is positive relationship between repeat customers and customer rating, there is not any single hotel type dominating the customers rating

# %%
sns.scatterplot(x="Rooms_Booked", y="Net_Profit", hue="Event_Season", data=df)
plt.title("Scatterplot for analaysing Rooms_Booked and Net_Profit with respect to Event_Season")
plt.xlabel("Rooms_Booked")
plt.ylabel("Net_Profit")
plt.show()

# %% [markdown]
# The visualization indicates that there is positive relationship between rooms booked and net profit. Wedding and Conference seasons have highest net profit for the rooms booked and Off season have lowest net profit

# %%
sns.scatterplot(x="Operating_Cost", y="Net_Profit", hue="City", data=df)
plt.title("Scatterplot for analaysing Operating_Cost and Net_Profit with respect to City")
plt.xlabel("Operating_Cost")
plt.ylabel("Net_Profit")
plt.show()

# %% [markdown]
# The visualization indicates that there no trend in operating cost and net profit. There is high profit at lowest opearting cost and for highest operating cost the profit is on low to medium scale. There is not a single city dominating the net profit

# %%
plt.figure(figsize=(8, 5))
sns.violinplot(data=df, x='Hotel_Type', y='Occupancy_Rate', hue='Hotel_Type', palette="tab10", legend=False)
plt.title("Distribution of Occupancy_Rate by Hotel_Type")
plt.xlabel("Hotel_Type")
plt.ylabel("Occupancy_Rate")
plt.show()

# %% [markdown]
# - **All hotel types have mostly similar probability around 60% to 90%**
# - **Business hotels usually have the highest occupancy rate**
# - **Budget hotels are not stable**
# - **Luxury and Resort hotels have good occupancy but have some variation**

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="Hotel_Type",y="Avg_Room_Price",hue="Event_Season",data=df)
plt.title("Boxplot for Hotel_Type and Avg_Room_Price with respect to Event_Season")
plt.xlabel("Hotel_Type")
plt.ylabel("Avg_Room_Price")
plt.show()

# %% [markdown]
# The visualization indicates that Luxury and Resort have highest room price and Budget type have lowest room prices. Festive season and conference have higher room prices so the median is low for that seasons, Off season have low room prices.

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="day_name",y="Occupancy_Rate",hue="Event_Season",data=df)
plt.title("Boxplot for day_name and Occupancy_Rate with respect to Event_Season")
plt.xlabel("day_name")
plt.ylabel("Occupancy_Rate")
plt.show()

# %% [markdown]
# The visualization indicates that Wedding and Conference have highest median occupancy rate almost on most of days Festive seasons have leow median and Off Season have lowest median occupancy rate on Saturday

# %%
sns.boxplot(x="Hotel_Type",y="Customer_Rating",hue="Event_Season",data=df)
plt.title("Boxplot for Hotel_Type and Customer_Rating with respect to Event_Season")
plt.xlabel("Hotel_Type")
plt.ylabel("Customer_Rating")
plt.show()

# %% [markdown]
# The visualization indicates that wedding season have highest median rating. In budget type all seasons have highest median rating.
# Luxury and Resort have higher ratings on Festive seasons

# %%
sns.boxplot(x="day_name",y="Occupancy_Rate",hue="City",data=df)
plt.title("Boxplot for day_name and Occupancy_Rate with respect to City")
plt.xlabel("day_name")
plt.ylabel("Occupancy_Rate")
plt.show()

# %% [markdown]
# The visualization indicates that on Friday and Saturday there is highest median occupancy rate in most of cities.
# Occupancy rate changes slightly by cities.

# %%
data = ['Occupancy_Rate','Avg_Room_Price','Daily_Revenue']
corr_data = df[data]
sns.heatmap(corr_data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# - **Occupancy rate is positively correlated with daily revenue 0.21 and average room price 0.10**
# - **Average room price is positively correlated with daily revenue**

# %%
data = ['Rooms_Available','Avg_Room_Price']
corr_data = df[data]
sns.heatmap(corr_data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# - **Average room price is positively correlated with rooms available 0.69**

# %%
data = ['Rooms_Booked','Operating_Cost']
corr_data = df[data]
sns.heatmap(corr_data.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# - **Operating cost is positively correlated with rooms booked 0.03**

# %%
sns.pairplot(df, vars=['Avg_Room_Price', 'Occupancy_Rate', 'Daily_Revenue', 'Net_Profit'])
plt.show()

# %% [markdown]
# The visualization indicates that Avg room price is positively related with Daily revenue and Net profit. Daily revenue is related with net profit.
# Net profit is related with occupancy rate.
# As the room prices will increases profit and revenue also increases.

# %%
ct1 = pd.crosstab(df['Hotel_Type'], df['Event_Season'])

# %%
ct1.plot(kind="bar",figsize=(10,8))
plt.title("Distribution of Hotel_Type wise Event_Season")
plt.xlabel("Hotel_Type")
plt.ylabel("Event_Season")
plt.show()

# %% [markdown]
# The visulization indicates that In Off season there is highest visits of customers for all types of hotels.
# For wedding customers mostly prefer Luxury and Resort types, For festive seasons Budget type is mostly preffered.

# %%
ct3 = pd.crosstab(df['City'],df['Hotel_Type'],values=df['Daily_Revenue'],aggfunc='mean')

# %%
sns.heatmap(ct3,annot=True, cmap='Blues')
plt.title("Average Daily Revenue by Hotel Type and City")
plt.xlabel("Hotel Type")
plt.ylabel("City")
plt.show()

# %% [markdown]
# The visualization indicates that Luxury hotels across all cities have highest average daily revenue followed by Resort type. Budget type hotels generate lowest daily revenue.
# Mumbai and Delhi have highest revenue for Luxury and Resort types.

# %%
sns.lineplot(data=df, x='Month', y='Profit_Margin_Percent')
plt.title('Profit Margin Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Profit Margin (%)')
plt.show()

# %% [markdown]
# - **This shows the positive trend, profit margins increasing from around 78% to about 86%**
# - **There are some fluctuations in this graph**

# %%
sns.lineplot(data=df, x='Year', y='Profit_Margin_Percent')
plt.title('Profit Margin Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Profit Margin (%)')
plt.show()

# %% [markdown]
# - **This shows the negative trend, profit margin decreases around 83.1% to 82.5%**
# - **There is no fluctuation in this graph**

# %%
plt.boxplot(df['Rooms_Available'])
plt.title('Rooms_Available Distribution Box Plot')
plt.ylabel('Rooms_Available')
plt.show()

# %% [markdown]
# - **The data is distributed between 10 to 223 range.**
# - **The 50% rooms available between 100 to 125 range.**
# - **The median of rooms available is near 120**
# - **There are no outliers found in this column**

# %%
IQR = 161.000000 - 84.000000	
print(IQR)
lower_limit = 84.000000 - 1.5 * IQR
print(lower_limit)
upper_limit = 161.000000 + 1.5 * IQR
print(upper_limit)
# Out:
# 77.0
# -31.5
# 276.5

# %%
plt.boxplot(df['Rooms_Booked'])
plt.title('Rooms_Booked Distribution Box Plot')
plt.ylabel('Rooms_Booked')
plt.show()

# %% [markdown]
# - **The data is distributed between 25 to 205 range**
# - **The 50% of rooms booked is between 65 to 120 range**
# - **The median is near 85 percent of rooms booked**
# - **There are extreme high level outliers in this column**

# %%
IQR = 118.000000 - 60.000000	
print(IQR)
lower_limit = 60.000000 - 1.5 * IQR
print(lower_limit)
upper_limit = 118.000000 + 1.5 * IQR
print(upper_limit)
# Out:
# 58.0
# -27.0
# 205.0

# %%
plt.boxplot(df['Occupancy_Rate'])
plt.title('Occupancy_Rate Distribution Box Plot')
plt.ylabel('Occupancy_Rate')
plt.show()

# %% [markdown]
# - **The data is distributed between 45 to 97 range**
# - **The 50% of occupancy rate is between 70 to 80 range**
# - **The median is near 75 percent occupancy rate**
# - **There are extreme low level outliers in this column**

# %%
IQR = 80.000000 - 65.850000	
print(IQR)
lower_limit = 65.850000 - 1.5 * IQR
print(lower_limit)
upper_limit = 80.000000 + 1.5 * IQR
print(upper_limit)
# Out:
# 14.150000000000006
# 44.624999999999986
# 101.22500000000001

# %%
plt.boxplot(df['Avg_Room_Price'])
plt.title('Avg_Room_Price Distribution Box Plot')
plt.ylabel('Avg_Room_Price')
plt.show()

# %% [markdown]
# - **The data is distributed between 1000 to 20000 range**
# - **The 50% of average room price is between 5000 to 11000 range**
# - **The median average room price is near 7000**
# - **There are extreme high level outliers in this column**

# %%
IQR = 11021.822500 - 4835.447500	
print(IQR)
lower_limit = 4835.447500 - 1.5 * IQR
print(lower_limit)
upper_limit = 11021.822500 + 1.5 * IQR
print(upper_limit)
# Out:
# 6186.375
# -4444.115
# 20301.385000000002

# %%
plt.boxplot(df['Daily_Revenue'])
plt.title('Daily_Revenue Distribution Box Plot')
plt.ylabel('Daily_Revenue')
plt.show()

# %% [markdown]
# - **The data is distributed between 0.1 to 0.3 range**
# - **The 50% of daily revenue is between 0.1 to 0.2 range**
# - **The median is near 0.1 percent**
# - **There are extreme high level outliers in this column**

# %%
IQR = 1.327376e+06 - 2.793690e+05	
print(IQR)
lower_limit = 2.793690e+05 - 1.5 * IQR
print(lower_limit)
upper_limit = 1.327376e+06 + 1.5 * IQR
print(upper_limit)
# Out:
# 1048007.0
# -1292641.5
# 2899386.5

# %%
plt.boxplot(df['Operating_Cost'])
plt.title('Operating_Cost Distribution Box Plot')
plt.ylabel('Operating_Cost')
plt.show()

# %% [markdown]
# - **The data is distributed between 6000 to 7000 range**
# - **The median is near 6000 to 7000**
# - **There are extreme high level outliers in this column**

# %%
IQR = 60000.000000 - 60000.000000	
print(IQR)
lower_limit = 60000.000000 - 1.5 * IQR
print(lower_limit)
upper_limit = 60000.000000 + 1.5 * IQR
print(upper_limit)
# Out:
# 0.0
# 60000.0
# 60000.0

# %%
plt.boxplot(df['Net_Profit'])
plt.title('Net_Profit Distribution Box Plot')
plt.ylabel('Net_Profit')
plt.show()

# %% [markdown]
# - **The data is distributed between 0 to 3 range**
# - **The 50% of net profit is between 0 to 1.5 range**
# - **The median net profit is near 1**
# - **There are extreme high level outliers in this column**

# %%
IQR = 1.283420e+06 - 2.180708e+05	
print(IQR)
lower_limit = 2.180708e+05 - 1.5 * IQR
print(lower_limit)
upper_limit = 1.283420e+06 + 1.5 * IQR
print(upper_limit)
# Out:
# 1065349.2
# -1379952.9999999998
# 2881443.8

# %%
plt.boxplot(df['Profit_Margin_Percent'])
plt.title('Profit_Margin_Percent Distribution Box Plot')
plt.ylabel('Profit_Margin_Percent')
plt.show()

# %% [markdown]
# - **The data is distributed between 45 to 98 range**
# - **The 50% of profit margin percent is between 75 to 95 range**
# - **The median profit margin percent is near 90 percent**
# - **There are extreme low level outliers in this column**

# %%
IQR = 95.372500 - 76.865000	
print(IQR)
lower_limit = 76.865000 - 1.5 * IQR
print(lower_limit)
upper_limit = 95.372500 + 1.5 * IQR
print(upper_limit)
# Out:
# 18.507500000000007
# 49.103749999999984
# 123.13375000000002

# %%
plt.boxplot(df['Customer_Rating'])
plt.title('Customer_Rating Distribution Box Plot')
plt.ylabel('Customer_Rating')
plt.show()

# %% [markdown]
# - **The data is distributed between 2.7 to 4.7 range**
# - **The 50% of customer rating is between 3.5 to 4.2 range**
# - **The median customer rating is near 3.7 percent**
# - **There are extreme low and high level outliers in this column**

# %%
IQR = 4.100000 - 3.500000	
print(IQR)
lower_limit = 3.500000 - 1.5 * IQR
print(lower_limit)
upper_limit = 4.100000 + 1.5 * IQR
print(upper_limit)
# Out:
# 0.5999999999999996
# 2.6000000000000005
# 4.999999999999999

# %%
plt.boxplot(df['Cancellations'])
plt.title('Cancellations Distribution Box Plot')
plt.ylabel('Cancellations')
plt.show()

# %% [markdown]
# - **The data is distributed between 0 to 5 range**
# - **The 50% of cancellations is between 0 to 2 range**
# - **The median cancellation is near 1 percent**
# - **There are extreme high level outliers in this column**

# %%
IQR = 68.500000 - 58.807500	
print(IQR)
lower_limit = 58.807500 - 1.5 * IQR
print(lower_limit)
upper_limit = 68.500000 + 1.5 * IQR
print(upper_limit)
# Out:
# 9.692500000000003
# 44.26875
# 83.03875000000001

# %%
df.dtypes
# Out:
# Booking_ID                          object
# Hotel_Name                          object
# City                                object
# Hotel_Type                          object
# Date                        datetime64[ns]
# Rooms_Available                      int64
# Rooms_Booked                         int64
# Occupancy_Rate                     float64
# Avg_Room_Price                     float64
# Daily_Revenue                      float64
# Operating_Cost                     float64
# Net_Profit                         float64
# Profit_Margin_Percent              float64
# Customer_Rating                    float64
# Cancellations                      float64
# Event_Season                        object
# Repeat_Customers_Percent           float64
# Month                                int32
# Year                                 int32
# month_name                          object
# day_name                            object
# quarter                              int32
# ...
